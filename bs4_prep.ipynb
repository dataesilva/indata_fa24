# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
jobs = requests.get('https://www.usajobs.gov/Search/Results?jt=Data%20Analyst&k=Data%20Analyst',
                   headers = {'User-agent': 'Mozilla/5.0'})

# %%
jobs.status_code
# Out:
# 200

# %%
with open('jobs.html', 'w') as text:
    text.write(jobs.text)

# %%
jobs_soup = BeautifulSoup(jobs.text, 'html.parser')
# soup

# %%
games = requests.get('https://steamcommunity.com/discussions/forum/7/',
                   headers = {'User-agent': 'Mozilla/5.0'})

# %%
games_soup = BeautifulSoup(games.text, 'html.parser')
# games_soup

# %%
games_soup.find_all(name = 'div')
# Out:
# [<div class="responsive_page_frame with_header">
#  <div aria-label="Mobile Menu" class="responsive_page_menu_ctn mainmenu" role="navigation">
#  <div class="responsive_page_menu" id="responsive_page_menu">
#  <div class="mainmenu_contents">
#  <div class="mainmenu_contents_items">
#  <a class="menuitem" href="https://steamcommunity.com/login/home/?goto=discussions%2Fforum%2F7%2F">
#  									Login								</a>
#  <a class="menuitem supernav" data-tooltip-content=".submenu_Store" data-tooltip-type="selector" href="https://store.steampowered.com/">
#  				Store			</a>
#  <div class="submenu_Store" data-submenuid="Store" style="display: none;">
#  <a class="submenuitem" href="https://store.steampowered.com/">
#  						Home											</a>
#  <a class="submenuitem" href="https://store.steampowered.com/explore/">
#  						Discovery Queue											</a>
#  <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">
#  						Wishlist											</a>
# ...

# %%
games_soup.find_all(name = 'option')
# Out:
# [<option class="" value="https://steamcommunity.com/discussions/forum/30/">New to Steam</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/1/">Help and Tips</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/10/">Suggestions / Ideas</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/0/">Steam Discussions</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/2/">Steam for Mac</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/8/">Steam Mobile</option>,
#  <option class="" selected="" value="https://steamcommunity.com/discussions/forum/7/">Steam Community</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/9/">VAC Discussion</option>,
#  <option class="" value="https://steamcommunity.com/discussions/forum/11/">Hardware and Operating Systems</option>,
# ...

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topics_container'})
# Out:
# [<div class="forum_topics_container" data-panel='{"autoFocus":true}' id="forum_General_4009259_7_topiccontainer">
#  <div class="forum_topics" id="forum_General_4009259_7_topics">
#  <div class="forum_topic unread" data-gidforumtopic="7074686901648720741" data-panel='{"clickOnActivate":"firstChild"}' data-tooltip-forum='			&lt;div class="topic_hover_text"&gt;
#  				Hi,
#
#  26 - F here looking for more female gamers out there to play with.
#  ːsteamhappyː			&lt;/div&gt;
#  			&lt;div class="topic_hover_row"&gt;
#  				Posted by: &lt;span class="topic_hover_data"&gt;Sackers&lt;/span&gt;, &lt;span class=""&gt;12:18pm&lt;/span&gt;			&lt;/div&gt;
#  							&lt;div class="topic_hover_row"&gt;
#  					Last post: &lt;span class="topic_hover_data"&gt;Sackers&lt;/span&gt;, &lt;span class=""&gt;1:03pm&lt;/span&gt;				&lt;/div&gt;
#  								' id="forum_General_4009259_7_7074686901648720741">
# ...

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0]
# Out:
# <div class="forum_topic unread" data-gidforumtopic="7074686901648720741" data-panel='{"clickOnActivate":"firstChild"}' data-tooltip-forum='			&lt;div class="topic_hover_text"&gt;
# 				Hi,
#
# 26 - F here looking for more female gamers out there to play with.
# ːsteamhappyː			&lt;/div&gt;
# 			&lt;div class="topic_hover_row"&gt;
# 				Posted by: &lt;span class="topic_hover_data"&gt;Sackers&lt;/span&gt;, &lt;span class=""&gt;12:18pm&lt;/span&gt;			&lt;/div&gt;
# 							&lt;div class="topic_hover_row"&gt;
# 					Last post: &lt;span class="topic_hover_data"&gt;Sackers&lt;/span&gt;, &lt;span class=""&gt;1:03pm&lt;/span&gt;				&lt;/div&gt;
# 								' id="forum_General_4009259_7_7074686901648720741">
# <a class="forum_topic_overlay" href="https://steamcommunity.com/discussions/forum/7/7074686901648720741/">
# </a>
# <div class="forum_topic_details">
# <div class="forum_topic_reply_count">
# ...

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0].div.find_all(name = 'div')[1]
# Out:
# <div class="forum_topic_lastpost" data-timestamp="1732050180" title="November 19, 2024 @ 1:03:00 pm PST">
# 					13 minutes ago				</div>

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0].div.find_all(name = 'div')[1]['title']
# Out:
# 'November 19, 2024 @ 1:03:00 pm PST'

# %%
[x.div.find_all(name = 'div')[1]['title'] for x in games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})]
# Out:
# ['November 19, 2024 @ 1:03:00 pm PST',
#  'November 19, 2024 @ 12:28:23 pm PST',
#  'November 19, 2024 @ 12:00:10 pm PST',
#  'November 19, 2024 @ 11:31:54 am PST',
#  'November 19, 2024 @ 10:46:46 am PST',
#  'November 19, 2024 @ 9:45:09 am PST',
#  'November 19, 2024 @ 9:45:01 am PST',
#  'November 19, 2024 @ 8:42:10 am PST',
#  'November 19, 2024 @ 7:30:24 am PST',
#  'November 19, 2024 @ 5:36:48 am PST',
#  'November 19, 2024 @ 3:11:22 am PST',
#  'November 19, 2024 @ 1:25:51 am PST',
#  'November 19, 2024 @ 12:59:08 am PST',
#  'November 19, 2024 @ 12:57:46 am PST',
#  'November 18, 2024 @ 11:41:02 pm PST']

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0].find_all(name = 'div', attrs = {'class': 'forum_topic_name'})
# Out:
# [<div class="forum_topic_name">
#  															Female Gamers						</div>]

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0].find_all(name = 'div', attrs = {'class': 'forum_topic_name'})[0].text
# Out:
# '\r\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\tFemale Gamers\t\t\t\t\t\t'

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0].find_all(name = 'div', attrs = {'class': 'forum_topic_name'})[0].text.strip()
# Out:
# 'Female Gamers'

# %%
[x for x in games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})]

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic unread'})[0].div.get_attribute_list('class')
# Out:
# ['forum_topic_details']

# %%
topic_hover_text

# %%
games_soup.find_all(name = 'div', attrs = {'class': 'forum_topic  unread'})
# Out:
# []

# %%
soup.find_all(name = 'div', attrs = {'class': 'usajobs-search-result--core'})
# Out:
# []

# %%
soup.find_all(name = 'a', attrs = {'itemprop': 'title'})
# Out:
# []

# %%
soup.find_all(name = 'a', attrs = {'class': 'usajobs-search-result-0'})
# Out:
# []
