# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
ces = pd.read_csv(r"C:\Users\dsilva2\Dropbox\Kent\EMAT-8_62110_Interactive Data\cces_example_data.csv")
ces.head()
# Out:
#    pew_religimp  pew_churatd  sex  educ  nonwhite  age  faminc_new  pid3  \
# 0             2            6    2     2         1   56           6     1
# 1             2            4    2     5         1   53          13     1
# 2             1            2    1     2         1   69          10     2
# 3             2            3    1     6         1   76          97     1
# 4             4            5    2     6         1   83           4     1
#
#    ideo5  QueerPhobia  ...  InterGBiasParty  InterGBiasCand  InterGBiasSup  \
# 0      1     1.000000  ...              -99             -99            -96
# 1      2     3.000000  ...             -100            -100           -100
# 2      5     4.333333  ...               99              99             96
# 3      3     1.000000  ...              -86             -91            -89
# 4      2     1.000000  ...              -80             -88            -87
#
# ...

# %%
ces['Evaluation'].sum()
# Out:
# 584

# %%
ces.groupby('Evaluation')['caseid'].count()
# Out:
# Evaluation
# 0    365
# 1     48
# 2    202
# 3     44
# Name: caseid, dtype: int64
