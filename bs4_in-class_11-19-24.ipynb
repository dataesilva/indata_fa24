# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
header = {'User-agent': 'Mozilla/5.0'}
jobs = requests.get('https://www.usajobs.gov/Search/Results?j=1560&l=Kent%2C%20Ohio&l=Kent%2C%20Ohio&k=Data%20Science%20Series&p=1', headers = header)

# %%
jobs.status_code
# Out:
# 200

# %%
BeautifulSoup(jobs.text)
# Out:
# <!DOCTYPE html>
# <html class="flexbox" lang="en">
# <head>
# <title>USAJOBS - Search</title>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/css/bundle-usaj-design-system.css?v=7yYqeT8ouaP-khu9BccQt3ZgAzypE0n4RSJI-PyUcsg" rel="stylesheet"/>
# <link href="/css/bundle-usaj-search-layout.css?v=g8HShXi_FY83F9rV5Q--4-aRFDZywhlVuDU0bj9__CE" rel="stylesheet"/>
# </head>
# <body>
# <a aria-label="top of the page" href="#" id="top"></a>
# <header aria-label="header" class="usajobs-site-header">
# <div class="usa-banner">
# <div class="usa-accordion">
# <div class="usa-banner-header usajobs-nav--vTest__banner-header">
# <div class="usa-grid usa-banner-inner usajobs-nav--full_bleed__banner-inner">
# <div class="usa-width-one-half usajobs-nav--vTest__banner-inner">
# <img alt="U.S. flag" src="/img/png/us_flag_small.png"/>
# ...

# %%
with open('jobs_usa.html', 'w') as text:
    text.write(jobs.text)

# %%
games = requests.get('https://steamcommunity.com/discussions/forum/0/',
                     headers = header)
games.status_code
# Out:
# 200

# %%
games_soup = BeautifulSoup(games.text)
# games_soup

# %%
games_soup.div.div.a['href']
# Out:
# 'https://steamcommunity.com/login/home/?goto=discussions%2Fforum%2F0%2F'

# %%
games_soup.find_all(name = 'div',
                   attrs = {'class': 'stuff'})
# Out:
# []

# %%
games_soup.div
# Out:
# <div class="responsive_page_frame with_header">
# <div aria-label="Mobile Menu" class="responsive_page_menu_ctn mainmenu" role="navigation">
# <div class="responsive_page_menu" id="responsive_page_menu">
# <div class="mainmenu_contents">
# <div class="mainmenu_contents_items">
# <a class="menuitem" href="https://steamcommunity.com/login/home/?goto=discussions%2Fforum%2F0%2F">
# 									Login								</a>
# <a class="menuitem supernav" data-tooltip-content=".submenu_Store" data-tooltip-type="selector" href="https://store.steampowered.com/">
# 				Store			</a>
# <div class="submenu_Store" data-submenuid="Store" style="display: none;">
# <a class="submenuitem" href="https://store.steampowered.com/">
# 						Home											</a>
# <a class="submenuitem" href="https://store.steampowered.com/explore/">
# 						Discovery Queue											</a>
# <a class="submenuitem" href="https://steamcommunity.com/my/wishlist/">
# 						Wishlist											</a>
# ...

# %%
games_soup.find_all(name = 'div',
                    attrs = {'class': 'forum_topic unread'})
# Out:
# [<div class="forum_topic unread" data-gidforumtopic="4625854789815634657" data-panel='{"clickOnActivate":"firstChild"}' data-tooltip-forum='			&lt;div class="topic_hover_text"&gt;
#  				EFF YOU SEE KAY steam. Where is the support page? Oh? No where EXACTLY! F. YOU. SEE. K. Steam.			&lt;/div&gt;
#  			&lt;div class="topic_hover_row"&gt;
#  				Posted by: &lt;span class="topic_hover_data"&gt;Axiom&lt;/span&gt;, &lt;span class=""&gt;4:26pm&lt;/span&gt;			&lt;/div&gt;
#  							&lt;div class="topic_hover_row"&gt;
#  					Last post: &lt;span class="topic_hover_data"&gt;RPG Gamer Man&lt;/span&gt;, &lt;span class=""&gt;4:32pm&lt;/span&gt;				&lt;/div&gt;
#  								' id="forum_General_4009259_4625854789815634657">
#  <a class="forum_topic_overlay" href="https://steamcommunity.com/discussions/forum/0/4625854789815634657/">
#  </a>
#  <div class="forum_topic_details">
#  <div class="forum_topic_reply_count">
# ...

# %%
len(games_soup.find_all(name = 'div',
                    attrs = {'class': 'forum_topic unread'}))
# Out:
# 15

# %%
games_soup.find_all(name = 'div',
                    attrs = {'class': 'forum_topic unread'})[0].div.\
find(name = 'div', attrs = {'class':'forum_topic_lastpost'})['title']
# Out:
# 'November 19, 2024 @ 4:32:33 pm PST'

# %%
[x.div.find(name = 'div',
            attrs = {'class':'forum_topic_lastpost'})['title']
 for x in games_soup.find_all(name = 'div',
                              attrs = {'class': 'forum_topic unread'})]
# Out:
# ['November 19, 2024 @ 4:32:33 pm PST',
#  'November 19, 2024 @ 4:30:47 pm PST',
#  'November 19, 2024 @ 4:27:54 pm PST',
#  'November 19, 2024 @ 4:27:11 pm PST',
#  'November 19, 2024 @ 4:26:11 pm PST',
#  'November 19, 2024 @ 4:22:32 pm PST',
#  'November 19, 2024 @ 4:17:00 pm PST',
#  'November 19, 2024 @ 4:14:57 pm PST',
#  'November 19, 2024 @ 3:44:06 pm PST',
#  'November 19, 2024 @ 3:35:19 pm PST',
#  'November 19, 2024 @ 3:15:04 pm PST',
#  'November 19, 2024 @ 2:10:57 pm PST',
#  'November 19, 2024 @ 2:01:45 pm PST',
#  'November 19, 2024 @ 2:00:36 pm PST',
#  'November 19, 2024 @ 1:54:05 pm PST']

# %%
games_soup.find_all(name = 'div',
                    attrs = {'class': 'forum_topic unread'})[0]
# Out:
# <div class="forum_topic unread" data-gidforumtopic="4625854789815634657" data-panel='{"clickOnActivate":"firstChild"}' data-tooltip-forum='			&lt;div class="topic_hover_text"&gt;
# 				EFF YOU SEE KAY steam. Where is the support page? Oh? No where EXACTLY! F. YOU. SEE. K. Steam.			&lt;/div&gt;
# 			&lt;div class="topic_hover_row"&gt;
# 				Posted by: &lt;span class="topic_hover_data"&gt;Axiom&lt;/span&gt;, &lt;span class=""&gt;4:26pm&lt;/span&gt;			&lt;/div&gt;
# 							&lt;div class="topic_hover_row"&gt;
# 					Last post: &lt;span class="topic_hover_data"&gt;RPG Gamer Man&lt;/span&gt;, &lt;span class=""&gt;4:32pm&lt;/span&gt;				&lt;/div&gt;
# 								' id="forum_General_4009259_4625854789815634657">
# <a class="forum_topic_overlay" href="https://steamcommunity.com/discussions/forum/0/4625854789815634657/">
# </a>
# <div class="forum_topic_details">
# <div class="forum_topic_reply_count">
# ...

# %%
games_soup.find_all(name = 'div',
                    attrs = {'class': 'forum_topic unread'})[0].\
find(name = 'div', attrs = {'class': 'forum_topic_op'}).text.strip()
# Out:
# 'Axiom'

# %%
[x.find(name = 'div', attrs = {'class': 'forum_topic_op'}).text.strip() for x in games_soup.find_all(name = 'div',
                    attrs = {'class': 'forum_topic unread'})]
# Out:
# ['Axiom',
#  'Axiom',
#  'kycaver',
#  '\U000e0021\U000e0021\U000e0021\u2067\u2067自閉症猫',
#  '[CZ] Colonel Clanny',
#  'Straight White Male',
#  'Dr. Smoothbrain',
#  'lex-iplg',
#  'Nosteru',
#  'Yujah',
#  '𝔇𝔞𝔯𝔨𝔪𝔞𝔫',
#  'BUILT different',
#  'TapewormJim (TJ)',
#  'Balalaika',
#  'Der Geselle']
